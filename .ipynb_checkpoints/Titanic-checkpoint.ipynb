# %%
#biblioteca para efetuar calculos
#leitura de arquivos e grandes BDs
#criação de graficos
import numpy as nd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')

# %%
#Bilbiotecas default para Machine learning
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, label_binarize
import catboost
from sklearn.model_selection import train_test_split
from sklearn import model_selection, tree, preprocessing, metrics, linear_model
from sklearn.svm import LinearSVC
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression, LogisticRegression, SGDClassifier
from sklearn.tree import DecisionTreeClassifier
from catboost import CatBoostClassifier, Pool, cv

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# ### Importando os arquivos

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
gender_submission = pd.read_csv('gender_submission.csv')

# %% [markdown]
# ### Abrindo arquivos

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
test
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# ...

# %%
test.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
#salvamos o passengerID para o arquivo que vamos enviar para o Kaglle
passengerId = train['PassengerId']

#criamos um novo DF (o que sera mandado para o kaglle)
titanic_df = pd.concat([train, test], ignore_index=True)
train_index = len(train)
test_index = len(titanic_df) - len(test)

# %%
titanic_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# Criando o df onde iremos processar os modelos de ML
df = pd.DataFrame()

# %% [markdown]
# ### Survived

# %%
sns.countplot(data = titanic_df, x = 'Survived')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
# Criando uma função para ajudar no momento de visualizar as informações de cada coluna
#data recebeu como valor (data = titanic_df, x = 'Survived')

def titanic_func(data, column, count = True):
    print(f'Quantidade de valores únicos: {data[column].nunique()}')
    print(f'\nQuais são os valores únicos: {data[column].unique()}')
    print(f'\nQuantidade de valores nulos: {data[column].isnull().sum()}')
    print(f'\nQuantidade por opção: \n{data[column].value_counts()}')
    
    if count == True:
        sns.countplot(data = data, x = column, hue = 'Survived')
    else:
        sns.displot(data[column], kde = True)
    
    
titanic_func(titanic_df, 'Survived')
# Out:
# Quantidade de valores únicos: 2
#
# Quais são os valores únicos: [ 0.  1. nan]
#
# Quantidade de valores nulos: 418
#
# Quantidade por opção:
# Survived
# 0.0    549
# 1.0    342
# Name: count, dtype: int64

# %%
#nosso data frame vai receber os valores de sobreviventes de titanic_df
df['Survived'] = titanic_df['Survived']

# %%
df
# Out:
#       Survived
# 0          0.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          0.0
# ...        ...
# 1304       NaN
# 1305       NaN
# 1306       NaN
# 1307       NaN
# 1308       NaN
#
# [1309 rows x 1 columns]

# %% [markdown]
# ### Pclass

# %%
titanic_df['Pclass'].unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
titanic_func(titanic_df, 'Pclass')
# Out:
# Quantidade de valores únicos: 3
#
# Quais são os valores únicos: [3 1 2]
#
# Quantidade de valores nulos: 0
#
# Quantidade por opção:
# Pclass
# 3    709
# 1    323
# 2    277
# Name: count, dtype: int64

# %%
df['Pclass'] = titanic_df['Pclass']
df
# Out:
#       Survived  Pclass
# 0          0.0       3
# 1          1.0       1
# 2          1.0       3
# 3          1.0       1
# 4          0.0       3
# ...        ...     ...
# 1304       NaN       3
# 1305       NaN       1
# 1306       NaN       3
# 1307       NaN       3
# 1308       NaN       3
#
# [1309 rows x 2 columns]

# %% [markdown]
# ### Sexo

# %%
#verificar sexo

# %%
titanic_df['Sex'].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
#substituir os valores de "male" e "female" para 0 e 1
titanic_df['Sex']=titanic_df['Sex'].replace(['female','male'],[0, 1])
titanic_func(titanic_df, 'Sex')
# Out:
# Quantidade de valores únicos: 0
#
# Quais são os valores únicos: [nan]
#
# Quantidade de valores nulos: 1309
#
# Quantidade por opção:
# Series([], Name: count, dtype: int64)

# %%
df['Sex'] = titanic_df['Sex']
df
# Out:
#       Survived  Pclass  Sex
# 0          0.0       3    1
# 1          1.0       1    0
# 2          1.0       3    0
# 3          1.0       1    0
# 4          0.0       3    1
# ...        ...     ...  ...
# 1304       NaN       3    1
# 1305       NaN       1    0
# 1306       NaN       3    1
# 1307       NaN       3    1
# 1308       NaN       3    1
#
# [1309 rows x 3 columns]

# %% [markdown]
# ### Age

# %%
titanic_func(titanic_df, 'Age', False)
# Out:
# Quantidade de valores únicos: 98
#
# Quais são os valores únicos: [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.   22.5  18.5  67.   76.   26.5  60.5  11.5
#   0.33  0.17 38.5 ]
#
# Quantidade de valores nulos: 263
#
# Quantidade por opção:
# Age
# 24.0    47
# 22.0    43
# 21.0    41
# 30.0    40
# 18.0    39
#         ..
# 23.5     1
# 70.5     1
# 55.5     1
# 20.5     1
# 38.5     1
# Name: count, Length: 98, dtype: int64

# %%
#fazer uma correlação entre as idades
corr_df = titanic_df.select_dtypes(include=['number'])
corr_df.corr()

#correlaciona as idades sendo mais perto de 1 mais relacionado e mais perto de -1, menos
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.038354  0.013406  0.028814 -0.055224
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.077221 -0.035322
# Pclass         -0.038354 -0.338481  1.000000  0.124617 -0.408106  0.060832
# Sex             0.013406 -0.543351  0.124617  1.000000  0.063645 -0.109609
# Age             0.028814 -0.077221 -0.408106  0.063645  1.000000 -0.243699
# SibSp          -0.055224 -0.035322  0.060832 -0.109609 -0.243699  1.000000
# Parch           0.008942  0.081629  0.018322 -0.213125 -0.150917  0.373587
# Fare            0.031428  0.257307 -0.558629 -0.185523  0.178740  0.160238
#
#                 Parch      Fare
# PassengerId  0.008942  0.031428
# Survived     0.081629  0.257307
# Pclass       0.018322 -0.558629
# Sex         -0.213125 -0.185523
# Age         -0.150917  0.178740
# SibSp        0.373587  0.160238
# Parch        1.000000  0.221539
# ...

# %%
#media de idades de acordo com cada classe
titanic_df[titanic_df['Pclass'] == 1]['Age'].mean()
# Out:
# 39.15992957746479

# %%
titanic_df[titanic_df['Pclass'] == 2]['Age'].mean()
# Out:
# 29.506704980842912

# %%
titanic_df[titanic_df['Pclass'] == 3]['Age'].mean()
# Out:
# 24.81636726546906

# %%
for i in sorted(titanic_df['Pclass'].unique()):
    print(f"Pessoas da {i}ª classe tem a média de idade de: {titanic_df[titanic_df['Pclass'] == i]['Age'].mean():.0f} anos.")
# Out:
# Pessoas da 1ª classe tem a média de idade de: 39 anos.
# Pessoas da 2ª classe tem a média de idade de: 30 anos.
# Pessoas da 3ª classe tem a média de idade de: 25 anos.

# %%
titanic_df['Age'].isnull().sum()
# Out:
# 263

# %%
for i in titanic_df.index:
    
    if pd.isnull(titanic_df.loc[i, 'Age']):
        if titanic_df.loc[i, 'Pclass'] == 1:
            titanic_df.loc[i, 'Age'] = round(titanic_df[titanic_df['Pclass'] == 1]['Age'].mean())
        elif titanic_df.loc[i, 'Pclass'] == 2:
            titanic_df.loc[i, 'Age'] = round(titanic_df[titanic_df['Pclass'] == 2]['Age'].mean())
        elif titanic_df.loc[i, 'Pclass'] == 3:
            titanic_df.loc[i, 'Age'] = round(titanic_df[titanic_df['Pclass'] == 3]['Age'].mean())
            
    else:
        continue

# %%
titanic_df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Age'] = titanic_df['Age']
df
# Out:
#       Survived  Pclass  Sex   Age
# 0          0.0       3    1  22.0
# 1          1.0       1    0  38.0
# 2          1.0       3    0  26.0
# 3          1.0       1    0  35.0
# 4          0.0       3    1  35.0
# ...        ...     ...  ...   ...
# 1304       NaN       3    1  25.0
# 1305       NaN       1    0  39.0
# 1306       NaN       3    1  38.5
# 1307       NaN       3    1  25.0
# 1308       NaN       3    1  25.0
#
# [1309 rows x 4 columns]

# %% [markdown]
# ### SibSp

# %%
titanic_func(titanic_df, 'SibSp')
# Out:
# Quantidade de valores únicos: 7
#
# Quais são os valores únicos: [1 0 3 4 2 5 8]
#
# Quantidade de valores nulos: 0
#
# Quantidade por opção:
# SibSp
# 0    891
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: count, dtype: int64

# %% [markdown]
# ### Adicionar esposa/irmaos

# %%
df['SibSp'] = titanic_df['SibSp']
df
# Out:
#       Survived  Pclass  Sex   Age  SibSp
# 0          0.0       3    1  22.0      1
# 1          1.0       1    0  38.0      1
# 2          1.0       3    0  26.0      0
# 3          1.0       1    0  35.0      1
# 4          0.0       3    1  35.0      0
# ...        ...     ...  ...   ...    ...
# 1304       NaN       3    1  25.0      0
# 1305       NaN       1    0  39.0      0
# 1306       NaN       3    1  38.5      0
# 1307       NaN       3    1  25.0      0
# 1308       NaN       3    1  25.0      1
#
# [1309 rows x 5 columns]

# %%
#Agora vamos verificar o numero de pais ou filhos que acompanham cada passageiro e somar no family size
titanic_func(titanic_df,'Parch')
# Out:
# Quantidade de valores únicos: 8
#
# Quais são os valores únicos: [0 1 2 5 3 4 6 9]
#
# Quantidade de valores nulos: 0
#
# Quantidade por opção:
# Parch
# 0    1002
# 1     170
# 2     113
# 3       8
# 5       6
# 4       6
# 6       2
# 9       2
# Name: count, dtype: int64

# %%
df['Parch'] = titanic_df['Parch']
df
# Out:
#       Survived  Pclass  Sex   Age  SibSp  Parch
# 0          0.0       3    1  22.0      1      0
# 1          1.0       1    0  38.0      1      0
# 2          1.0       3    0  26.0      0      0
# 3          1.0       1    0  35.0      1      0
# 4          0.0       3    1  35.0      0      0
# ...        ...     ...  ...   ...    ...    ...
# 1304       NaN       3    1  25.0      0      0
# 1305       NaN       1    0  39.0      0      0
# 1306       NaN       3    1  38.5      0      0
# 1307       NaN       3    1  25.0      0      0
# 1308       NaN       3    1  25.0      1      1
#
# [1309 rows x 6 columns]

# %%
df['Family Size'] = titanic_df['Parch'] + titanic_df['SibSp'] + 1
df
# Out:
#       Survived  Pclass  Sex   Age  SibSp  Parch  Family Size
# 0          0.0       3    1  22.0      1      0            2
# 1          1.0       1    0  38.0      1      0            2
# 2          1.0       3    0  26.0      0      0            1
# 3          1.0       1    0  35.0      1      0            2
# 4          0.0       3    1  35.0      0      0            1
# ...        ...     ...  ...   ...    ...    ...          ...
# 1304       NaN       3    1  25.0      0      0            1
# 1305       NaN       1    0  39.0      0      0            1
# 1306       NaN       3    1  38.5      0      0            1
# 1307       NaN       3    1  25.0      0      0            1
# 1308       NaN       3    1  25.0      1      1            3
#
# [1309 rows x 7 columns]

# %% [markdown]
# ### Fare

# %%
titanic_func(titanic_df, 'Fare', False)
# Out:
# Quantidade de valores únicos: 281
#
# Quais são os valores únicos: [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55    31.275    7.8542  16.      29.125
#   13.      18.       7.225   26.       8.0292  35.5     31.3875 263.
#    7.8792   7.8958  27.7208 146.5208   7.75    10.5     82.1708  52.
#    7.2292  11.2417   9.475   21.      41.5792  15.5     21.6792  17.8
#   39.6875   7.8     76.7292  61.9792  27.75    46.9     80.      83.475
#   27.9     15.2458   8.1583   8.6625  73.5     14.4542  56.4958   7.65
#   29.      12.475    9.       9.5      7.7875  47.1     15.85    34.375
#   61.175   20.575   34.6542  63.3583  23.      77.2875   8.6542   7.775
#   24.15     9.825   14.4583 247.5208   7.1417  22.3583   6.975    7.05
#   14.5     15.0458  26.2833   9.2167  79.2      6.75    11.5     36.75
#    7.7958  12.525   66.6      7.3125  61.3792   7.7333  69.55    16.1
# ...

# %%
titanic_df['Fare'].mean()
# Out:
# 33.29547928134557

# %%
titanic_df[titanic_df['Fare'].isnull()]
# Out:
#       PassengerId  Survived  Pclass                Name  Sex   Age  SibSp  \
# 1043         1044       NaN       3  Storey, Mr. Thomas  NaN  60.5      0
#
#       Parch Ticket  Fare Cabin Embarked
# 1043      0   3701   NaN   NaN        S

# %%
titanic_df[titanic_df['Pclass']==3]['Fare'].mean()
# Out:
# 13.302888700564973

# %%
titanic_df['Fare'].fillna(titanic_df[titanic_df['Pclass'] == 3]['Fare'].mean())
# Out:
# 0         7.2500
# 1        71.2833
# 2         7.9250
# 3        53.1000
# 4         8.0500
#           ...
# 1304      8.0500
# 1305    108.9000
# 1306      7.2500
# 1307      8.0500
# 1308     22.3583
# Name: Fare, Length: 1309, dtype: float64

# %%
df['Fare'] = titanic_df['Fare']
df
# Out:
#       Survived  Pclass  Sex   Age  SibSp  Parch  Family Size      Fare
# 0          0.0       3    1  22.0      1      0            2    7.2500
# 1          1.0       1    0  38.0      1      0            2   71.2833
# 2          1.0       3    0  26.0      0      0            1    7.9250
# 3          1.0       1    0  35.0      1      0            2   53.1000
# 4          0.0       3    1  35.0      0      0            1    8.0500
# ...        ...     ...  ...   ...    ...    ...          ...       ...
# 1304       NaN       3    1  25.0      0      0            1    8.0500
# 1305       NaN       1    0  39.0      0      0            1  108.9000
# 1306       NaN       3    1  38.5      0      0            1    7.2500
# 1307       NaN       3    1  25.0      0      0            1    8.0500
# 1308       NaN       3    1  25.0      1      1            3   22.3583
#
# [1309 rows x 8 columns]

# %% [markdown]
# ### Embarked

# %%
titanic_func(titanic_df, 'Embarked')
# Out:
# Quantidade de valores únicos: 3
#
# Quais são os valores únicos: ['S' 'C' 'Q' nan]
#
# Quantidade de valores nulos: 2
#
# Quantidade por opção:
# Embarked
# S    914
# C    270
# Q    123
# Name: count, dtype: int64

# %%
titanic_df['Embarked'].isnull().sum()
# Out:
# 2

# %%
titanic_df[titanic_df['Embarked'].isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62       1.0       1                        Icard, Miss. Amelie
# 829          830       1.0       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#      Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   NaN  38.0      0      0  113572  80.0   B28      NaN
# 829  NaN  62.0      0      0  113572  80.0   B28      NaN

# %%
#Como possui valores nulos em Embarked, verificar a media da Pclass para cada Plataforma e preencher
titanic_df[titanic_df['Embarked']== "C"]['Pclass'].mean()
# Out:
# 1.8518518518518519

# %%
titanic_df[titanic_df['Embarked']== "S"]['Pclass'].mean()
# Out:
# 2.3479212253829322

# %%
titanic_df['Embarked'].fillna('C', inplace = True)

# %%
titanic_df['Embarked'].isnull().sum()
# Out:
# 0

# %%
df['Embarked'] = titanic_df['Embarked']
df
# Out:
#       Survived  Pclass  Sex   Age  SibSp  Parch  Family Size      Fare  \
# 0          0.0       3    1  22.0      1      0            2    7.2500
# 1          1.0       1    0  38.0      1      0            2   71.2833
# 2          1.0       3    0  26.0      0      0            1    7.9250
# 3          1.0       1    0  35.0      1      0            2   53.1000
# 4          0.0       3    1  35.0      0      0            1    8.0500
# ...        ...     ...  ...   ...    ...    ...          ...       ...
# 1304       NaN       3    1  25.0      0      0            1    8.0500
# 1305       NaN       1    0  39.0      0      0            1  108.9000
# 1306       NaN       3    1  38.5      0      0            1    7.2500
# 1307       NaN       3    1  25.0      0      0            1    8.0500
# 1308       NaN       3    1  25.0      1      1            3   22.3583
#
#      Embarked
# 0           S
# 1           C
# 2           S
# 3           S
# 4           S
# ...       ...
# ...
